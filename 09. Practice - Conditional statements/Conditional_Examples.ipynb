# %% [markdown]
# # Conditional Statement ExamplesOne quick real example for each case.

# %% [markdown]
# ### 1. Biggest number among three

# %%
a, b, c = 12, 45, 30if a >= b and a >= c:    biggest = aelif b >= a and b >= c:    biggest = belse:    biggest = cprint("Biggest number is:", biggest)

# %% [markdown]
# ### 2. Prime number check

# %%
num = 29is_prime = Trueif num < 2:    is_prime = Falseelse:    for i in range(2, int(num ** 0.5) + 1):        if num % i == 0:            is_prime = False            breakprint(f"{num} is prime: {is_prime}")

# %% [markdown]
# ### 3. Highest age among people

# %%
ages = {"Alice": 25, "Bob": 32, "Charlie": 28}oldest_name = max(ages, key=ages.get)print(f"{oldest_name} has the highest age: {ages[oldest_name]}")

# %% [markdown]
# ### 4. Convert 24-hour time to 12-hour format

# %%
hour_24 = 14if hour_24 == 0:    hour_12, period = 12, "AM"elif hour_24 < 12:    hour_12, period = hour_24, "AM"elif hour_24 == 12:    hour_12, period = 12, "PM"else:    hour_12, period = hour_24 - 12, "PM"print(f"{hour_24}:00 -> {hour_12}:00 {period}")
