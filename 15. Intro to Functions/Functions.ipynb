# %% [markdown]
# FUNCTION : block of code to perform a specific task

# %% [markdown]
# SYNTAX : def Function_name(parameters):
#              #statements
#          function_name(input parameters)---------->we pass arguements
#
# WHY WE USE : Reusable, Less lines of code, Reduces complexity, maintains modularity
#
# Types of Functions: 1.Built in fucntions---len(),max(),min()
#                     2. User defined
#
# TYPES OF USER DEFINED :
# 1. WITH RETURN & parameters
# 2. WITH RETURN & WTHOUT Parameter
# 3. WITHOUT RETURN & WITH Parameter
# 4. WITHOUT RETURN & WITHOUT Parameter

# %%
def division():
    def div1(a,b):
        if b==0:
            print(f'div with {b} is not possible')
        else:
            return a//b
    result1=div1(10,5)
    print(result1)
    def div2():
        a,b=6,2
        return a//b
    div2()
    result2=div2()
    print(result2)
    def div3(a,b):
        print(a//b)
    div3(8,2)
    def div4():
        a=20
        b=10
        print(a//b)
    div4()
division()
# Out:
# 2
# 3
# 4
# 2

# %% [markdown]
# Based on arguements we can say functions into 5 types:
# 1. POSITONAL 2.KEYWORD 3. DEFAULT 4. Varaible-Length 5. Variable length-Keyword Arguements

# %%
a=[1,2,3,4]
def f1(x):
    x=[1,2,3,4]
    print(id(x))
    return x
result=f1(a)
print(id(a))
print(result)
# Out:
# 1724074887552
# 1724074889664
# [1, 2, 3, 4]

# %%
string="hiii"
print(id(string))             
x=string.replace("h","o")                   oiii
print(id(string))
print(x)
# Out:
# 1724047133888
# 1724047133888
# oiii
